# %% [markdown]
# Choose only the relevants to use in the repository as a .txt file.

# %%
# !pip freeze > requirements.txt
# Out:
# WARNING: Could not generate requirement for distribution -treamlit 0.61.0 (c:\users\danib\appdata\roaming\python\python36\site-packages): Parse error at "'-treamli'": Expected W:(abcd...)
# WARNING: Could not generate requirement for distribution -rotobuf 3.11.2 (c:\users\danib\appdata\roaming\python\python36\site-packages): Parse error at "'-rotobuf'": Expected W:(abcd...)
# WARNING: Could not generate requirement for distribution -ornado 6.0.4 (c:\programdata\anaconda3\lib\site-packages): Parse error at "'-ornado='": Expected W:(abcd...)
# WARNING: Could not generate requirement for distribution -ltk 3.4.4 (c:\programdata\anaconda3\lib\site-packages): Parse error at "'-ltk==3.'": Expected W:(abcd...)
# WARNING: Could not generate requirement for distribution - rnado (c:\programdata\anaconda3\lib\site-packages): Parse error at "'-===rnad'": Expected W:(abcd...)
# WARNING: Could not generate requirement for distribution -eautifulsoup4 4.9.1 (c:\programdata\anaconda3\lib\site-packages): Parse error at "'-eautifu'": Expected W:(abcd...)
# WARNING: Could not generate requirement for distribution -atplotlib 3.1.3 (c:\programdata\anaconda3\lib\site-packages): Parse error at "'-atplotl'": Expected W:(abcd...)

# %%
# !cat requirements.txt
# Out:
# absl-py==0.9.0
# altair==4.1.0
# altgraph==0.17
# anaconda-client==1.7.2
# anaconda-navigator==1.9.12
# appdirs==1.4.4
# arrow==0.15.6
# astor==0.8.1
# astunparse==1.6.3
# atomicwrites==1.4.0
# attrs==19.3.0
# audioread==2.1.8
# backcall==0.2.0
# base58==2.0.1
# beautifulsoup4==4.7.1
# binaryornot==0.4.4
# bleach==3.1.5
# blinker==1.4
# blis @ file:///C:/ci/cython-blis_1594240702768/work
# bokeh @ file:///C:/ci/bokeh_1593187680264/work
# boto==2.49.0
# boto3 @ file:///tmp/build/80754af9/boto3_1593439033587/work
# botocore @ file:///tmp/build/80754af9/botocore_1593435624439/work
# brotlipy==0.7.0
# cachetools==4.0.0
# catalogue==1.0.0
# certifi==2020.6.20
# cffi==1.14.0
# chardet==3.0.4
# chart-studio==1.0.0
# click==7.1.2
# clyent==1.2.2
# cmdstanpy==0.4.0
# colorama==0.4.3
# colorlover==0.3.0
# conda==4.8.3
# conda-build==3.18.11
# conda-package-handling==1.7.0
# convertdate==2.2.1
# cookiecutter==1.7.2
# cryptography==2.9.2
# cssselect==1.1.0
# cufflinks==0.17.0
# cycler==0.10.0
# cymem==2.0.3
# dataclasses==0.7
# deap==1.3.1
# decorator==4.4.2
# defusedxml==0.6.0
# deon==0.2.1
# dlib==19.8.1
# docutils==0.15.2
# emoji==0.5.4
# en-core-web-sm==2.2.5
# entrypoints==0.3
# enum-compat==0.0.3
# ephem==3.7.7.1
# es-core-news-sm==2.2.5
# fbprophet==0.6
# filelock==3.0.12
# fuzzywuzzy==0.18.0
# gast==0.3.3
# gensim==3.8.0
# glob2==0.7
# google-api-core==1.17.0
# google-auth==1.11.0
# google-auth-oauthlib==0.4.1
# google-cloud-core==1.3.0
# google-cloud-storage==1.28.0
# google-pasta==0.1.8
# google-resumable-media==0.5.0
# googleapis-common-protos==1.51.0
# grpcio==1.26.0
# h2o==3.30.0.3
# h5py==2.10.0
# holidays==0.10.2
# html5lib==0.9999999
# idna==2.9
# importlib-metadata @ file:///C:/ci/importlib-metadata_1593431910144/work
# imutils==0.5.3
# install==1.3.3
# ipykernel==5.3.0
# ipython @ file:///C:/ci/ipython_1593446240034/work
# ipython-genutils==0.2.0
# ipywidgets==7.5.1
# jedi @ file:///C:/ci/jedi_1592841982010/work
# Jinja2==2.11.2
# jinja2-time==0.2.0
# jmespath @ file:///tmp/build/80754af9/jmespath_1594304593830/work
# joblib @ file:///tmp/build/80754af9/joblib_1594236160679/work
# json5==0.9.5
# jsonschema==3.0.2
# jupyter-client @ file:///tmp/build/80754af9/jupyter_client_1594163838128/work
# jupyter-contrib-core==0.3.3
# jupyter-contrib-nbextensions==0.5.1
# jupyter-core==4.6.3
# jupyter-highlight-selected-word==0.2.0
# jupyter-latex-envs==1.4.6
# jupyter-nbextensions-configurator==0.4.1
# jupyterlab==2.1.5
# jupyterlab-server @ file:///tmp/build/80754af9/jupyterlab_server_1594164409481/work
# Keras==2.3.1
# Keras-Applications==1.0.8
# Keras-Preprocessing==1.1.0
# kiwisolver==1.2.0
# korean-lunar-calendar==0.2.1
# langdetect==1.0.8
# langid==1.1.6
# language-check==1.1
# libarchive-c==2.9
# librosa @ git+https://github.com/librosa/librosa@5d7314fa226355f96bdfb50a8a60282570cf5917
# llvmlite==0.33.0
# LunarCalendar==0.0.9
# lxml==4.5.2
# Markdown==3.1.1
# MarkupSafe==1.1.1
# matplotlib @ file:///C:/ci/matplotlib-base_1592846129657/work
# menuinst==1.4.16
# mistune==0.8.4
# mkl-fft==1.1.0
# mkl-random==1.1.1
# mkl-service==2.3.0
# mlxtend==0.17.2
# more-itertools==8.4.0
# murmurhash==1.0.2
# navigator-updater==0.2.1
# nbconvert==5.6.1
# nbformat==5.0.7
# nl-core-news-sm==2.2.5
# nltk==3.5
# notebook==6.0.3
# numba==0.50.1+0.gbfd9be18f.dirty
# numpy==1.18.4
# oauthlib==3.1.0
# olefile==0.46
# opencv-python==4.2.0.34
# opt-einsum==3.1.0
# packaging==20.4
# pandas @ file:///C:/ci/pandas_1592833608684/work
# pandas-bokeh==0.5
# pandocfilters==1.4.2
# parso==0.7.0
# pdf2image==1.11.0
# pefile==2019.4.18
# pickleshare==0.7.5
# Pillow @ file:///C:/ci/pillow_1594299032796/work
# pkginfo==1.5.0.1
# plac==1.1.3
# plotly @ file:///tmp/build/80754af9/plotly_1593522991827/work
# pluggy==0.13.1
# pooch==1.1.1
# poyo==0.5.0
# preshed==3.0.2
# prometheus-client==0.8.0
# prompt-toolkit==3.0.5
# protobuf==3.11.3
# psutil==5.7.0
# py==1.9.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# PyAudio==0.2.11
# pycontractions==2.0.1
# pycosat==0.6.3
# pycparser==2.20
# pydeck==0.4.0b2
# pydub==0.24.1
# pyemd==0.5.1
# PyGeoj==1.0.0
# Pygments==2.6.1
# PyInstaller==3.6
# PyJWT==1.7.1
# PyMeeus==0.3.7
# pyOpenSSL==19.1.0
# pyparsing==2.4.7
# pyreadline==2.1
# pyrsistent==0.16.0
# PySocks==1.7.1
# pystan==2.19.1.1
# pytest==5.4.3
# python-dateutil==2.8.1
# python-slugify==4.0.0
# python-twitter==3.5
# pytorch-pretrained-bert==0.6.2
# pytz==2020.1
# pywin32==227
# pywinpty==0.5.7
# PyYAML==5.3.1
# pyzmq==19.0.1
# QtPy==1.9.0
# regex @ file:///C:/ci/regex_1593422126140/work
# requests==2.23.0
# requests-oauthlib==1.3.0
# resampy==0.2.2
# retrying==1.3.3
# rpy2==3.1.0
# rsa==4.0
# ruamel-yaml==0.15.87
# s3transfer==0.3.3
# sacremoses==0.0.43
# scikit-learn @ file:///C:/ci/scikit-learn_1592853528256/work
# scipy==1.4.1
# seaborn==0.10.1
# Send2Trash==1.5.0
# sentencepiece==0.1.90
# seqeval==0.0.12
# setuptools-git==1.2
# simplegeneric==0.8.1
# simpletransformers==0.28.2
# six==1.14.0
# smart-open @ file:///tmp/build/80754af9/smart_open_1594236772807/work
# sounddevice==0.3.15
# SoundFile==0.10.3.post1
# soupsieve==2.0.1
# spacy @ file:///C:/ci/spacy_1594303380509/work
# SpeechRecognition==3.8.1
# spotipy==2.8.0
# srsly==1.0.2
# stopit==1.1.2
# tabulate==0.8.7
# tensorboard==2.2.1
# tensorboard-plugin-wit==1.6.0.post3
# tensorboardX==2.0
# tensorflow==2.2.0
# tensorflow-estimator==2.2.0
# termcolor==1.1.0
# terminado==0.8.3
# testpath==0.4.4
# text-unidecode==1.3
# textblob==0.15.3
# textblob-nl==0.0.1
# thinc @ file:///C:/ci/thinc_1594243573812/work
# threadpoolctl @ file:///tmp/tmp9twdgx9k/threadpoolctl-2.1.0-py3-none-any.whl
# tokenizers==0.7.0
# torch==1.3.1
# torchvision==0.2.1
# tornado==5.1.1
# TPOT==0.11.4
# tqdm @ file:///tmp/build/80754af9/tqdm_1593446365756/work
# traitlets==4.3.3
# transformers==2.9.1
# tweepy==3.8.0
# twitter==1.18.0
# typing-extensions @ file:///tmp/build/80754af9/typing_extensions_1592847887441/work
# tzlocal==2.0.0
# unicode==2.7
# Unidecode==1.1.1
# update-checker==0.17
# urllib3==1.25.9
# validators==0.15.0
# wasabi==0.6.0
# wcwidth @ file:///tmp/build/80754af9/wcwidth_1593447189090/work
# webencodings==0.5.1
# Werkzeug==1.0.1
# widgetsnbextension==3.5.1
# win-inet-pton==1.1.0
# wincertstore==0.2
# wordcloud==1.6.0
# wrapt==1.11.2
# xgboost==1.1.0
# xmltodict==0.12.0
# zipp==3.1.0

# %%
# To install requirements

#!pip install -r /path/to/requirements.txt

# !pip install --user --requirement requirements.txt
# Out:
# absl-py==0.8.0
# astor==0.8.0
# astroid==2.3.1
# astropy==3.2.1
# atomicwrites==1.3.0
# attrs==19.1.0
# backcall==0.1.0
# beautifulsoup4==4.7.1
# bleach==3.1.0
# blis==0.2.4
# bokeh==1.0.4
# boto==2.49.0
# boto3==1.9.111
# botocore==1.12.111
# branca==0.3.1
# bz2file==0.98
# cachetools==3.1.0
# certifi==2018.11.29
# chardet==3.0.4
# Click==7.0
# colorama==0.4.1
# colorlover==0.3.0
# confuse==1.0.0
# cufflinks==0.14.6
# cycler==0.10.0
# cymem==2.0.2
# cytoolz==0.9.0.1
# deap==1.3.0
# decorator==4.3.2
# defusedxml==0.5.0
# docutils==0.14
# en-core-web-sm==2.1.0
# entrypoints==0.3
# folium==0.10.0
# ftfy==4.4.3
# funcy==1.11
# future==0.17.1
# gast==0.2.2
# gensim==3.7.1
# google-pasta==0.1.7
# grpcio==1.24.1
# h5py==2.10.0
# html5lib==1.0.1
# htmlmin==0.1.12
# idna==2.8
# ijson==2.3
# imbalanced-learn==0.4.3
# imblearn==0.0
# ipykernel==5.1.0
# ipython==7.2.0
# ipython-genutils==0.2.0
# ipywidgets==7.4.2
# isort==4.3.21
# jedi==0.13.2
# jellyfish==0.7.2
# Jinja2==2.10
# jmespath==0.9.4
# joblib==0.13.2
# jsonschema==2.6.0
# jupyter==1.0.0
# jupyter-client==5.2.4
# jupyter-console==6.0.0
# jupyter-contrib-core==0.3.3
# jupyter-contrib-nbextensions==0.5.1
# jupyter-core==4.4.0
# jupyter-highlight-selected-word==0.2.0
# jupyter-latex-envs==1.4.6
# jupyter-nbextensions-configurator==0.4.1
# kaggle==1.5.3
# Keras==2.3.1
# Keras-Applications==1.0.8
# Keras-Preprocessing==1.1.0
# kiwisolver==1.0.1
# langdetect==1.0.7
# language-check==1.1
# lazy-object-proxy==1.4.2
# lenskit==0.5.0
# llvmlite==0.27.0
# lxml==4.3.2
# Markdown==3.1.1
# MarkupSafe==1.1.0
# matplotlib==3.0.2
# mccabe==0.6.1
# missingno==0.4.2
# mistune==0.8.4
# mock==2.0.0
# more-itertools==6.0.0
# murmurhash==1.0.2
# mwparserfromhell==0.5.3
# nbconvert==5.4.1
# nbformat==4.4.0
# networkx==2.3
# nltk==3.4
# nose==1.3.7
# notebook==5.7.4
# numba==0.42.0
# numexpr==2.6.9
# numpy==1.17.2
# oauthlib==3.0.1
# opencv-python==4.1.1.26
# opt-einsum==3.1.0
# packaging==19.0
# pandas==0.25.3
# pandas-profiling==2.3.0
# pandocfilters==1.4.2
# parso==0.3.3
# patsy==0.5.1
# pbr==5.1.3
# phik==0.9.8
# pickleshare==0.7.5
# Pillow==5.4.1
# plac==0.9.6
# plotly==3.6.1
# pluggy==0.9.0
# preprocessor==1.1.3
# preshed==2.0.1
# prometheus-client==0.5.0
# prompt-toolkit==2.0.8
# protobuf==3.10.0
# py==1.8.0
# pyahocorasick==1.4.0
# pyarrow==0.11.1
# pycontractions==2.0.1
# pyemd==0.5.1
# Pygments==2.3.1
# pyLDAvis==2.1.2
# pylint==2.4.2
# pyparsing==2.3.1
# Pyphen==0.9.5
# pysocks==1.7.1
# pytest==4.3.0
# pytest-pylint==0.14.1
# python-dateutil==2.7.5
# python-Levenshtein==0.12.0
# python-slugify==3.0.2
# python-twitter==3.5
# pytz==2018.9
# pywinpty==0.5.5
# PyYAML==3.13
# pyzmq==17.1.2
# qtconsole==4.5.5
# requests==2.21.0
# requests-oauthlib==1.2.0
# retrying==1.3.3
# s3transfer==0.2.0
# sacremoses==0.0.35
# scattertext==0.0.2.43
# scikit-learn==0.22
# scipy==1.3.3
# seaborn==0.9.0
# Send2Trash==1.5.0
# singledispatch==3.4.0.3
# six==1.12.0
# sklearn==0.0
# smart-open==1.8.0
# soupsieve==1.9.1
# spacy==2.1.3
# spotipy==2.4.4
# srsly==0.0.5
# statsmodels==0.9.0
# stopit==1.1.2
# tensorboard==2.0.0
# tensorflow==2.0.0
# tensorflow-estimator==2.0.0
# termcolor==1.1.0
# terminado==0.8.1
# testpath==0.4.2
# text-unidecode==1.2
# textblob==0.15.3
# textsearch==0.0.17
# thinc==7.0.4
# toolz==0.9.0
# tornado==5.1.1
# TPOT==0.11.0
# tqdm==4.40.2
# traitlets==4.3.2
# tweepy==3.5.0
# typed-ast==1.4.0
# unicode==2.7
# Unidecode==1.0.23
# update-checker==0.16
# urllib3==1.24.1
# vaderSentiment==3.2.1
# wasabi==0.2.0
# wcwidth==0.1.7
# webencodings==0.5.1
# Werkzeug==0.16.0
# widgetsnbextension==3.4.2
# wordcloud==1.5.0
# wrapt==1.11.2
# xgboost==0.82
# xlrd==1.2.0
# WARNING: Could not generate requirement for distribution -pencv-python 4.1.1.26 (c:\program files\python37\lib\site-packages): Parse error at "'-pencv-p'": Expected W:(abcd...)
